# %% [markdown]
# ## **MLP para classificação binária**
# **Dataset Ionosphere**
# - Dataset de texto com previsão da existência de uma estrutura na atomosfera com dados de um radar
# - Classificação "good" significa evidência de estrutura na ionosfera e "bad" o contrário
# - 34 atributos contínuos (numéricos) e o 35º é a classificação de "good"/"bad" com "g"/"b"
# - 350 instâncias

# %% [markdown]
# ## Pipeline de um processo de Deep Learning implementado em PyTorch:
#
#     1. Preparar os Dados
#     2. Definir o Modelo
#     3. Treinar o Modelo
#     4. Avaliar o Modelo
#     5. Usar o Modelo

# %% [markdown]
# ## Melhoramento do Modelo

# %%
# Confirmar a instalação

import torch
print(torch.__version__)
# Out:
# 1.8.1+cu101

# %% [markdown]
# ## Imports

# %%
# pytorch mlp for binary classification
import time
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch import Tensor
from torch.nn import Linear
from torch.nn import ReLU
from torch.nn import Sigmoid
from torch.nn import Module
from torch.optim import SGD, Adam
from torch.nn import BCELoss, BCEWithLogitsLoss
from torch.nn.init import kaiming_uniform_
from torch.nn.init import xavier_uniform_

np.random.seed(0) 
torch.manual_seed(0)
import random
random.seed(0)

# %%
#####ir buscar o dataset:
#!wget -c https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv -O ionosphere.csv

# %%
#Constants

#path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv'
PATH = 'ionosphere.csv'
#setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')


#force cpu
#device = torch.device("cpu")
print('Using device:', device)
print()


EPOCHS = 50
BATCH_SIZE = 64
LEARNING_RATE = 0.001
# Out:
# Quadro P6000
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# Using device: cuda

# %% [markdown]
# ## *1. Preparar os Dados

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset

# definição classe para o dataset
class CSVDataset(Dataset):
    # ler o dataset
    def __init__(self, path):
        # ler o ficheiro csv para um dataframe
        df = pd.read_csv(path, header=None)
        # separar os inputs e os outputs
        self.X = df.values[:, :-1]
        self.y = df.values[:, -1]
        # garantir que os inputs sejam floats
        self.X = self.X.astype('float32')
        # fazer o encoding dos outputs (label) e garantir que sejam floats
        self.y = LabelEncoder().fit_transform(self.y) #faz o fit e transforma no self.y o 'g' e o 'b' em 0 e 1
        self.y = self.y.astype('float32')
        self.y = self.y.reshape((len(self.y), 1))   
        
    # número de casos no dataset
    def __len__(self):
        return len(self.X)
 
    # retornar um caso
    def __getitem__(self, idx):
        return [self.X[idx], self.y[idx]]
 
    # retornar índices para casos de treino e de teste
    def get_splits(self, n_test=0.33):
        # calcular o tamanho para o split
        test_size = round(n_test * len(self.X))
        train_size = len(self.X) - test_size
        # calcular o split do houldout
        return random_split(self, [train_size, test_size], generator=torch.Generator().manual_seed(42))
    
        # Stratified Sampling for train and test
    def get_splits_strat(self, n_test=0.33):
        train_X, test_X, train_y, test_y = train_test_split(self.X, self.y, 
                                             test_size=n_test,
                                             random_state=999,
                                             shuffle=True,
                                             stratify=self.y)
        train = TensorDataset(torch.from_numpy(train_X),torch.from_numpy(train_y))
        test = TensorDataset(torch.from_numpy(test_X),torch.from_numpy(test_y))
        return train, test
    
# preparar o dataset
def prepare_data(path):
    # criar uma instância do dataset
    dataset = CSVDataset(path)
    # calcular o split
    train, test = dataset.get_splits()
    print('sem strat',type(train))
    # preparar os data loaders
    train_dl = DataLoader(train, batch_size=len(train), shuffle=True) #32 len(train)
    test_dl = DataLoader(test, batch_size=1024, shuffle=False)
    train_dl_all = DataLoader(train, batch_size=len(train), shuffle=False)
    test_dl_all = DataLoader(test, batch_size=len(test), shuffle=False)
    return train_dl, test_dl, train_dl_all, test_dl_all

# preparar o dataset
def prepare_data_strat(path):
    # criar uma instância do dataset
    dataset = CSVDataset(path)
    # calcular o split
    train, test = dataset.get_splits_strat()
    print('com strat',type(train))
    # preparar os data loaders
    train_dl = DataLoader(train, batch_size=len(train), shuffle=True) #32 len(train)
    test_dl = DataLoader(test, batch_size=1024, shuffle=False)
    train_dl_all = DataLoader(train, batch_size=len(train), shuffle=False)
    test_dl_all = DataLoader(test, batch_size=len(test), shuffle=False)
    return train_dl, test_dl, train_dl_all, test_dl_all


# preparar os dados
train_dl, test_dl,  train_dl_all, test_dl_all = prepare_data(PATH)

# sanity check
x,y = next(iter(train_dl))
print(x.shape, y.shape)
x,y = next(iter(test_dl))
print(x.shape, y.shape)

# preparar os dados
train_s_dl, test_s_dl,  train_s_dl_all, test_s_dl_all = prepare_data_strat(PATH)

# sanity check
x,y = next(iter(train_s_dl))
print(x.shape, y.shape)
x,y = next(iter(test_s_dl))
print(x.shape, y.shape)
# Out:
# sem strat <class 'torch.utils.data.dataset.Subset'>
# torch.Size([235, 34]) torch.Size([235, 1])
# torch.Size([116, 34]) torch.Size([116, 1])
# com strat <class 'torch.utils.data.dataset.TensorDataset'>
# torch.Size([235, 34]) torch.Size([235, 1])
# torch.Size([116, 34]) torch.Size([116, 1])

# %% [markdown]
# ## *1.1 Visualizar os Dados

# %%
from IPython.display import display

def visualize_data(path):
    # criar uma instância do dataset
    df = pd.read_csv(path, header=None)
    display(df)

def visualize_dataset(train_dl, test_dl):
    print(f"Quantidade de casos de Treino:{len(train_dl.dataset)}") 
    print(f"Quantidade de casos de Teste:{len(test_dl.dataset)}")
    x, y = next(iter(train_dl)) #fazer uma iteração nos loaders para ir buscar um batch de casos
    print(f"Shape tensor batch casos treino, input: {x.shape}, output: {y.shape}")
    x, y = next(iter(test_dl))  
    print(f"Shape tensor batch casos teste, input: {x.shape}, output: {y.shape}")

visualize_data(PATH)
visualize_dataset(train_dl, test_dl)
# Out:
#      0   1        2        3        4        5        6        7        8   \
# 0     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 346   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
#           9   ...       25       26       27       28       29       30  \
# 0    0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1   -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2    0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3    0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4   -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
# ..       ...  ...      ...      ...      ...      ...      ...      ...
# 346 -0.04622  ... -0.04202  0.83479  0.00123  1.00000  0.12815  0.86660
# 347  0.01606  ...  0.01361  0.93522  0.04925  0.93159  0.08168  0.94066
# 348  0.02446  ...  0.03193  0.92489  0.02542  0.92120  0.02242  0.92459
# 349  0.00110  ... -0.02099  0.89147 -0.07760  0.82983 -0.17238  0.96022
# 350 -0.09139  ... -0.15114  0.81147 -0.04822  0.78207 -0.00703  0.75747
#
#           31       32       33  34
# 0   -0.54487  0.18641 -0.45300   g
# 1   -0.06288 -0.13738 -0.02447   b
# 2   -0.24180  0.56045 -0.38238   g
# 3    1.00000 -0.32382  1.00000   b
# 4   -0.59573 -0.04608 -0.65697   g
# ..       ...      ...      ...  ..
# 346 -0.10714  0.90546 -0.04307   g
# 347 -0.00035  0.91483  0.04712   g
# 348  0.00442  0.92697 -0.00577   g
# 349 -0.03757  0.87403 -0.16243   g
# 350 -0.06678  0.85764 -0.06151   g
#
# [351 rows x 35 columns]
# Quantidade de casos de Treino:235
# Quantidade de casos de Teste:116
# Shape tensor batch casos treino, input: torch.Size([235, 34]), output: torch.Size([235, 1])
# Shape tensor batch casos teste, input: torch.Size([116, 34]), output: torch.Size([116, 1])

# %% [markdown]
# ## *1.2 Verificar balanceamento do dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def visualize_holdout_balance(train_dl, test_dl):
    _, y_train = next(iter(train_dl))                            
    _, y_test = next(iter(test_dl))

    sns.set_style('whitegrid')
    casos_treino=len(y_train) # calcular o nº de casos de treino
    casos_test=len(y_test) # calcular o nº de casos de teste
    b_Train=np.count_nonzero(y_train == 0) # calcular o nº de 0 nos casos de treino
    g_Train = np.count_nonzero(y_train == 1) # calcular o nº de 1 nos casos de treino
    b_Test=np.count_nonzero(y_test == 0) # calcular o nº de 0 nos casos de teste
    g_Test = np.count_nonzero(y_test == 1) # calcular o nº de 1 nos casos de teste
    print("casos_treino:",casos_treino)
    print("g_Train: ", g_Train)
    print("b_Train: ", b_Train)
    print("g_Train/b_Train: ", g_Train/b_Train) # rácio de g em b
    print("casos_test:",casos_test)
    print("g_Test: ", g_Test)
    print("b_Test: ", b_Test)
    print("g_Test/b_Test: ", g_Test/b_Test) # rácio de g em b

    grafico=sns.barplot(x=['g_Train','b_Train', 'g_Test', 'b_Test'], 
                        y=[g_Train,b_Train, g_Test, b_Test])
    grafico.set_title('Data balance ')
    plt.xticks(rotation=70)
    plt.tight_layout()
    plt.show() 
    
visualize_holdout_balance(train_dl_all, test_dl_all)
# Out:
# casos_treino: 235
# g_Train:  156
# b_Train:  79
# g_Train/b_Train:  1.9746835443037976
# casos_test: 116
# g_Test:  69
# b_Test:  47
# g_Test/b_Test:  1.4680851063829787

# %%
visualize_holdout_balance(train_s_dl_all, test_s_dl_all)
# Out:
# casos_treino: 235
# g_Train:  151
# b_Train:  84
# g_Train/b_Train:  1.7976190476190477
# casos_test: 116
# g_Test:  74
# b_Test:  42
# g_Test/b_Test:  1.7619047619047619

# %% [markdown]
# ## *2. Definir o Modelo

# %%
#### Instalar o torchinfo
#!pip install torchinfo

# %%
from torchinfo import summary

# Definição da classe para o modelo
class MLP(Module):
    # definir elementos do modelo
    def __init__(self, n_inputs):
        super(MLP, self).__init__()
        # input para a primeira camada - Linear - ReLU
        self.hidden1 = Linear(n_inputs, 10)
        kaiming_uniform_(self.hidden1.weight, nonlinearity='relu') # He initialization
        self.act1 = ReLU()
        # segunda camada - Linear - ReLU
        self.hidden2 = Linear(10, 8)
        kaiming_uniform_(self.hidden2.weight, nonlinearity='relu')
        self.act2 = ReLU()
        # terceira camada e output Linear - Sigmoid
        self.hidden3 = Linear(8, 1)
        xavier_uniform_(self.hidden3.weight) # Glorot initialization
        self.act3 = Sigmoid()
 
    # sequência de propagação do input 
    def forward(self, X):
        # input para a primeira camada
        X = self.hidden1(X)
        X = self.act1(X)
        # input para a segunda camada
        X = self.hidden2(X)
        X = self.act2(X)
        # input para a terceira camada e output
        X = self.hidden3(X)
        X = self.act3(X)
        return X
 
# definir a rede neuronal
model1 = MLP(34)
model2 = MLP(34)
# visualizar a rede
batch_size = 32
# sumário da rede
print(summary(model1, input_size=(batch_size, 34), device=device, verbose=0)) #verbose=2 Show weight and bias layers in full detail
model1.to(device)
model2.to(device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLP                                      [32, 1]                   --
# ├─Linear: 1-1                            [32, 10]                  350
# ├─ReLU: 1-2                              [32, 10]                  --
# ├─Linear: 1-3                            [32, 8]                   88
# ├─ReLU: 1-4                              [32, 8]                   --
# ├─Linear: 1-5                            [32, 1]                   9
# ├─Sigmoid: 1-6                           [32, 1]                   --
# ==========================================================================================
# Total params: 447
# Trainable params: 447
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ==========================================================================================
# MLP(
#   (hidden1): Linear(in_features=34, out_features=10, bias=True)
#   (act1): ReLU()
#   (hidden2): Linear(in_features=10, out_features=8, bias=True)
#   (act2): ReLU()
#   (hidden3): Linear(in_features=8, out_features=1, bias=True)
#   (act3): Sigmoid()
# )

# %% [markdown]
# ## *3. Treinar o Modelo

# %%
## Instalar o livelossplot
#!pip install livelossplot

# %%
#versão com display de gráfico
from livelossplot import PlotLosses

# define accuracy function
def binary_acc(pred, target):
    pred_tag = torch.round(pred)

    correct_results_sum = (pred_tag == target).sum().float()
    #acc = correct_results_sum/target.shape[0]
    #acc = acc*100
    acc=correct_results_sum 
    return acc


# treino do modelo
def train_model(train_dl, model):
    liveloss = PlotLosses() # para visualizarmos o processo de treino
    # definir a função de loss e a função de otimização
    # criterion = BCELoss() # Binary Cross Entropy - precisa de signoid como função de ativação na saida
    criterion = BCEWithLogitsLoss()
    # optimizer = SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9) # stochastic gradient descent
    optimizer = Adam(model.parameters(), lr=LEARNING_RATE)
    # iterar as epochs
    for epoch in range(EPOCHS):
        logs = {} # para visualizarmos o processo de treino
        # iterar as batchs
        epoch_loss  = 0.0 # para visualizarmos o processo de treino
        epoch_acc  = 0.0 # para visualizarmos o processo de treino
        for i, (inputs, labels) in enumerate(train_dl): # backpropagation
            # inicializar os gradientes
            inputs=inputs.to(device)
            labels=labels.to(device)
            optimizer.zero_grad() # coloca os gradientes de todos os parametros a zero
            # calcular o output do modelo - previsao/forward
            outputs = model(inputs)
            # calcular o loss
            loss = criterion(outputs, labels)
            # calcular a accuracy
            acc = binary_acc(outputs, labels)
            #acc = accuracy_score(outputs.detach().cpu().numpy().round(), labels.numpy(), normalize=False)
            # atribuição alteraçoes "In the backward pass we receive a Tensor containing the gradient of the loss
            # with respect to the output, and we need to compute the gradient of the loss with respect to the input.
            loss.backward() #backpropagation
            # update pesos do modelo
            optimizer.step()
            # calcular epochs de loss e epochs de accuracy
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
        epoch_loss = epoch_loss/len(train_dl.dataset)
        epoch_acc = epoch_acc/len(train_dl.dataset)
        print(f'Epoch {epoch:03}: | Loss: {epoch_loss:.5f} | Acc: {epoch_acc:.3f}')      
        logs['loss'] = epoch_loss # para visualizarmos o processo de treino
        logs['accuracy'] = epoch_acc # para visualizarmos o processo de treino
        liveloss.update(logs) # para visualizarmos o processo de treino
        liveloss.send() # para visualizarmos o processo de treino
 
# treinar o modelo
#%timeit train_model(train_dl, model1)

# %%
#%%timeit
# treinar o modelo

it = time.time()
train_model(train_dl, model1)
delta_t= time.time() - it
print(f'Execution time: {delta_t:.3} seconds')
# Out:
# accuracy
# 	accuracy         	 (min:    0.272, max:    0.732, cur:    0.719)
# Loss
# 	loss             	 (min:    0.003, max:    0.003, cur:    0.003)
# Execution time: 24.3 seconds

# %%
#%%timeit
train_model(train_s_dl, model2)
# Out:
# accuracy
# 	accuracy         	 (min:    0.116, max:    0.311, cur:    0.308)
# Loss
# 	loss             	 (min:    0.003, max:    0.003, cur:    0.003)

# %% [markdown]
# ## *4. Avaliar o Modelo

# %%
# Avaliar o modelo
def evaluate_model(test_dl, model):
    predictions = list()
    predictions_prob = list()
    actual_values = list()
    for i, (inputs, labels) in enumerate(test_dl):
        # avaliar o modelo com os casos de teste
        yprev = model(inputs)
        # retirar o array numpy
        yprev = yprev.detach().numpy()
        actual = labels.numpy()
        # arredondar para obter a classe
        predictions_prob.append(yprev) #vamos guardar tambem a probabilidade
        yprev = yprev.round()
        # guardar
        predictions.append(yprev)
        actual_values.append(actual)
    predictions_prob = np.vstack(predictions_prob)
    predictions = np.vstack(predictions)
    actual_values =  np.vstack(actual_values)
    return predictions_prob, predictions, actual_values
 
def display_confusion_matrix(cm):
    plt.figure(figsize = (16,8))
    sns.heatmap(cm,annot=True,xticklabels=['b','g'],yticklabels=['b','g'], annot_kws={"size": 12}, fmt='g', linewidths=.5)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# avaliar o modelo
predictions_prob, predictions, actual_values = evaluate_model(test_dl, model1)
#actuals, predictions = evaluate_model(train_dl, model)
# calcular a accuracy
acc = accuracy_score(actual_values, predictions)
print(f'Accuracy: {acc:0.3f}\n')

acertou=0
falhou = 0
for prob, r,p in zip(predictions_prob, actual_values, predictions):
    print(f'real:{r} probabilidade:{prob} previsão:{p}') 
    if r==p: acertou+=1  
    else: falhou+=1
print(f'acertou:{acertou} falhou:{falhou}')

# relatório de classificação: precision, recall, f1-score, support vs. 0,1, accuracy, macro avg, weighted avg
print(classification_report(actual_values, predictions))

# matriz confusão
cm = confusion_matrix(actual_values, predictions)
print (cm)
display_confusion_matrix(cm)
# Out:
# Accuracy: 0.638
#
# real:[1.] probabilidade:[0.48200014] previsão:[0.]
# real:[0.] probabilidade:[0.4865164] previsão:[0.]
# real:[1.] probabilidade:[0.835813] previsão:[1.]
# real:[0.] probabilidade:[0.6994164] previsão:[1.]
# real:[0.] probabilidade:[0.5126638] previsão:[1.]
# real:[1.] probabilidade:[0.6619957] previsão:[1.]
# real:[0.] probabilidade:[0.51990116] previsão:[1.]
# real:[1.] probabilidade:[0.7389484] previsão:[1.]
# real:[1.] probabilidade:[0.7787311] previsão:[1.]
# real:[1.] probabilidade:[0.6312392] previsão:[1.]
# real:[1.] probabilidade:[0.83776635] previsão:[1.]
# real:[1.] probabilidade:[0.8282216] previsão:[1.]
# real:[1.] probabilidade:[0.7292276] previsão:[1.]
# real:[0.] probabilidade:[0.6756298] previsão:[1.]
# real:[0.] probabilidade:[0.69020325] previsão:[1.]
# real:[0.] probabilidade:[0.4111096] previsão:[0.]
# real:[1.] probabilidade:[0.8786341] previsão:[1.]
# real:[1.] probabilidade:[0.84934753] previsão:[1.]
# real:[0.] probabilidade:[0.48937437] previsão:[0.]
# real:[0.] probabilidade:[0.62231755] previsão:[1.]
# real:[0.] probabilidade:[0.21309252] previsão:[0.]
# real:[1.] probabilidade:[0.5082163] previsão:[1.]
# real:[0.] probabilidade:[0.61415374] previsão:[1.]
# real:[0.] probabilidade:[0.65933716] previsão:[1.]
# real:[0.] probabilidade:[0.5285349] previsão:[1.]
# real:[1.] probabilidade:[0.7890204] previsão:[1.]
# real:[1.] probabilidade:[0.8683075] previsão:[1.]
# real:[0.] probabilidade:[0.86080885] previsão:[1.]
# real:[1.] probabilidade:[0.4899236] previsão:[0.]
# real:[0.] probabilidade:[0.86017764] previsão:[1.]
# real:[1.] probabilidade:[0.85963666] previsão:[1.]
# real:[1.] probabilidade:[0.4906344] previsão:[0.]
# real:[1.] probabilidade:[0.42466378] previsão:[0.]
# real:[0.] probabilidade:[0.54835844] previsão:[1.]
# real:[0.] probabilidade:[0.5298803] previsão:[1.]
# real:[0.] probabilidade:[0.91950005] previsão:[1.]
# real:[1.] probabilidade:[0.8739806] previsão:[1.]
# real:[0.] probabilidade:[0.32580727] previsão:[0.]
# real:[1.] probabilidade:[0.8293657] previsão:[1.]
# real:[1.] probabilidade:[0.7958825] previsão:[1.]
# real:[1.] probabilidade:[0.8403667] previsão:[1.]
# real:[1.] probabilidade:[0.7976285] previsão:[1.]
# real:[0.] probabilidade:[0.8222658] previsão:[1.]
# real:[0.] probabilidade:[0.6159634] previsão:[1.]
# real:[1.] probabilidade:[0.62054473] previsão:[1.]
# real:[0.] probabilidade:[0.74283534] previsão:[1.]
# real:[0.] probabilidade:[0.72985506] previsão:[1.]
# real:[1.] probabilidade:[0.5676296] previsão:[1.]
# real:[0.] probabilidade:[0.78664047] previsão:[1.]
# real:[1.] probabilidade:[0.8579725] previsão:[1.]
# real:[1.] probabilidade:[0.84750867] previsão:[1.]
# real:[1.] probabilidade:[0.7177092] previsão:[1.]
# real:[1.] probabilidade:[0.7991953] previsão:[1.]
# real:[1.] probabilidade:[0.85898733] previsão:[1.]
# real:[1.] probabilidade:[0.7650316] previsão:[1.]
# real:[1.] probabilidade:[0.59401184] previsão:[1.]
# real:[1.] probabilidade:[0.543322] previsão:[1.]
# real:[0.] probabilidade:[0.7165951] previsão:[1.]
# real:[0.] probabilidade:[0.50916064] previsão:[1.]
# real:[1.] probabilidade:[0.87154055] previsão:[1.]
# real:[1.] probabilidade:[0.88114333] previsão:[1.]
# real:[1.] probabilidade:[0.76460856] previsão:[1.]
# real:[0.] probabilidade:[0.5370996] previsão:[1.]
# real:[1.] probabilidade:[0.7672458] previsão:[1.]
# real:[0.] probabilidade:[0.3164087] previsão:[0.]
# real:[0.] probabilidade:[0.33187753] previsão:[0.]
# real:[1.] probabilidade:[0.88281614] previsão:[1.]
# real:[1.] probabilidade:[0.7890203] previsão:[1.]
# real:[0.] probabilidade:[0.67890674] previsão:[1.]
# real:[1.] probabilidade:[0.81622535] previsão:[1.]
# real:[1.] probabilidade:[0.81991565] previsão:[1.]
# real:[0.] probabilidade:[0.82257265] previsão:[1.]
# real:[1.] probabilidade:[0.7037375] previsão:[1.]
# real:[1.] probabilidade:[0.84308094] previsão:[1.]
# real:[1.] probabilidade:[0.8562231] previsão:[1.]
# real:[0.] probabilidade:[0.85252947] previsão:[1.]
# real:[1.] probabilidade:[0.79087704] previsão:[1.]
# real:[1.] probabilidade:[0.7620612] previsão:[1.]
# real:[0.] probabilidade:[0.73765683] previsão:[1.]
# real:[0.] probabilidade:[0.7714433] previsão:[1.]
# real:[0.] probabilidade:[0.63672787] previsão:[1.]
# real:[0.] probabilidade:[0.5243196] previsão:[1.]
# real:[1.] probabilidade:[0.87036055] previsão:[1.]
# real:[1.] probabilidade:[0.83900845] previsão:[1.]
# real:[1.] probabilidade:[0.80440044] previsão:[1.]
# real:[1.] probabilidade:[0.5827799] previsão:[1.]
# real:[1.] probabilidade:[0.80519295] previsão:[1.]
# real:[1.] probabilidade:[0.78671616] previsão:[1.]
# real:[1.] probabilidade:[0.6253144] previsão:[1.]
# real:[0.] probabilidade:[0.5394939] previsão:[1.]
# real:[0.] probabilidade:[0.7895641] previsão:[1.]
# real:[1.] probabilidade:[0.88011724] previsão:[1.]
# real:[1.] probabilidade:[0.8453799] previsão:[1.]
# real:[1.] probabilidade:[0.68776554] previsão:[1.]
# real:[1.] probabilidade:[0.86933166] previsão:[1.]
# real:[1.] probabilidade:[0.6941648] previsão:[1.]
# real:[1.] probabilidade:[0.77897245] previsão:[1.]
# real:[1.] probabilidade:[0.68258804] previsão:[1.]
# real:[0.] probabilidade:[0.5890316] previsão:[1.]
# real:[1.] probabilidade:[0.70816845] previsão:[1.]
# real:[0.] probabilidade:[0.4777189] previsão:[0.]
# real:[0.] probabilidade:[0.5750172] previsão:[1.]
# real:[1.] probabilidade:[0.80584604] previsão:[1.]
# real:[1.] probabilidade:[0.7926212] previsão:[1.]
# real:[0.] probabilidade:[0.7983418] previsão:[1.]
# real:[0.] probabilidade:[0.5462905] previsão:[1.]
# real:[0.] probabilidade:[0.5133088] previsão:[1.]
# real:[1.] probabilidade:[0.7663092] previsão:[1.]
# real:[1.] probabilidade:[0.68193156] previsão:[1.]
# real:[0.] probabilidade:[0.83864814] previsão:[1.]
# real:[1.] probabilidade:[0.75544256] previsão:[1.]
# real:[1.] probabilidade:[0.72946906] previsão:[1.]
# real:[0.] probabilidade:[0.39959204] previsão:[0.]
# real:[1.] probabilidade:[0.9130919] previsão:[1.]
# real:[0.] probabilidade:[0.5364045] previsão:[1.]
# real:[1.] probabilidade:[0.55323774] previsão:[1.]
# acertou:74 falhou:42
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.19      0.30        47
#          1.0       0.63      0.94      0.76        69
#
#     accuracy                           0.64       116
#    macro avg       0.66      0.57      0.53       116
# weighted avg       0.66      0.64      0.57       116
#
# [[ 9 38]
#  [ 4 65]]

# %%
# avaliar o modelo
predictions_prob, predictions, actual_values = evaluate_model(test_s_dl, model2)
#actuals, predictions = evaluate_model(train_dl, model)
# calcular a accuracy
acc = accuracy_score(actual_values, predictions)
print(f'Accuracy: {acc:0.3f}\n')

acertou=0
falhou = 0
for prob, r,p in zip(predictions_prob, actual_values, predictions):
    print(f'real:{r} probabilidade:{prob} previsão:{p}') 
    if r==p: acertou+=1  
    else: falhou+=1
print(f'acertou:{acertou} falhou:{falhou}')

# relatório de classificação: precision, recall, f1-score, support vs. 0,1, accuracy, macro avg, weighted avg
print(classification_report(actual_values, predictions))

# matriz confusão
cm = confusion_matrix(actual_values, predictions)
print (cm)
display_confusion_matrix(cm)
# Out:
# Accuracy: 0.750
#
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.4724673] previsão:[0.]
# real:[0.] probabilidade:[0.37310633] previsão:[0.]
# real:[1.] probabilidade:[0.50512433] previsão:[1.]
# real:[1.] probabilidade:[0.51506406] previsão:[1.]
# real:[1.] probabilidade:[0.5764106] previsão:[1.]
# real:[1.] probabilidade:[0.45360926] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.50120777] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.4677749] previsão:[0.]
# real:[0.] probabilidade:[0.01769458] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.4354042] previsão:[0.]
# real:[1.] probabilidade:[0.5007395] previsão:[1.]
# real:[0.] probabilidade:[0.2915413] previsão:[0.]
# real:[1.] probabilidade:[0.4954578] previsão:[0.]
# real:[1.] probabilidade:[0.5308081] previsão:[1.]
# real:[1.] probabilidade:[0.52159977] previsão:[1.]
# real:[0.] probabilidade:[0.51137954] previsão:[1.]
# real:[1.] probabilidade:[0.4660057] previsão:[0.]
# real:[0.] probabilidade:[0.28431383] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.5308165] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.5354754] previsão:[1.]
# real:[0.] probabilidade:[0.27130273] previsão:[0.]
# real:[1.] probabilidade:[0.4507726] previsão:[0.]
# real:[0.] probabilidade:[0.02106859] previsão:[0.]
# real:[1.] probabilidade:[0.46359792] previsão:[0.]
# real:[1.] probabilidade:[0.6232233] previsão:[1.]
# real:[0.] probabilidade:[0.301268] previsão:[0.]
# real:[0.] probabilidade:[0.21392891] previsão:[0.]
# real:[1.] probabilidade:[0.52788645] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.40999258] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.2379507] previsão:[0.]
# real:[1.] probabilidade:[0.47177434] previsão:[0.]
# real:[0.] probabilidade:[0.37310633] previsão:[0.]
# real:[1.] probabilidade:[0.5471671] previsão:[1.]
# real:[1.] probabilidade:[0.5205876] previsão:[1.]
# real:[1.] probabilidade:[0.5297063] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.45501775] previsão:[0.]
# real:[1.] probabilidade:[0.4772253] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.3808263] previsão:[0.]
# real:[1.] probabilidade:[0.52146465] previsão:[1.]
# real:[1.] probabilidade:[0.5238217] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.28548375] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.5649219] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.13022746] previsão:[0.]
# real:[0.] probabilidade:[0.06289016] previsão:[0.]
# real:[1.] probabilidade:[0.49452046] previsão:[0.]
# real:[0.] probabilidade:[0.56796354] previsão:[1.]
# real:[1.] probabilidade:[0.51009077] previsão:[1.]
# real:[1.] probabilidade:[0.5275419] previsão:[1.]
# real:[1.] probabilidade:[0.5254452] previsão:[1.]
# real:[1.] probabilidade:[0.52774197] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.5033422] previsão:[1.]
# real:[0.] probabilidade:[0.5293172] previsão:[1.]
# real:[0.] probabilidade:[0.34261033] previsão:[0.]
# real:[1.] probabilidade:[0.5624368] previsão:[1.]
# real:[0.] probabilidade:[0.15784365] previsão:[0.]
# real:[0.] probabilidade:[0.442083] previsão:[0.]
# real:[0.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.4643028] previsão:[0.]
# real:[0.] probabilidade:[0.53633624] previsão:[1.]
# real:[1.] probabilidade:[0.50132865] previsão:[1.]
# real:[0.] probabilidade:[0.36028188] previsão:[0.]
# real:[0.] probabilidade:[0.5247853] previsão:[1.]
# real:[0.] probabilidade:[0.17053099] previsão:[0.]
# real:[1.] probabilidade:[0.604705] previsão:[1.]
# real:[0.] probabilidade:[0.46454373] previsão:[0.]
# real:[0.] probabilidade:[0.05130938] previsão:[0.]
# real:[1.] probabilidade:[0.5290497] previsão:[1.]
# real:[1.] probabilidade:[0.50931835] previsão:[1.]
# real:[0.] probabilidade:[0.5295836] previsão:[1.]
# real:[1.] probabilidade:[0.45484608] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.03586368] previsão:[0.]
# real:[0.] probabilidade:[0.15799376] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.47938848] previsão:[0.]
# real:[0.] probabilidade:[0.3760658] previsão:[0.]
# real:[0.] probabilidade:[0.09762683] previsão:[0.]
# real:[1.] probabilidade:[0.53537035] previsão:[1.]
# real:[1.] probabilidade:[0.6067971] previsão:[1.]
# real:[1.] probabilidade:[0.47479287] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.12368568] previsão:[0.]
# real:[1.] probabilidade:[0.5261594] previsão:[1.]
# real:[0.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.60597575] previsão:[1.]
# real:[0.] probabilidade:[0.25976765] previsão:[0.]
# real:[1.] probabilidade:[0.38348594] previsão:[0.]
# real:[1.] probabilidade:[0.41313374] previsão:[0.]
# real:[0.] probabilidade:[0.00151091] previsão:[0.]
# real:[1.] probabilidade:[0.4976171] previsão:[0.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[0.] probabilidade:[0.5217388] previsão:[1.]
# real:[1.] probabilidade:[0.53576005] previsão:[1.]
# real:[1.] probabilidade:[0.49324164] previsão:[0.]
# real:[1.] probabilidade:[0.4834578] previsão:[0.]
# real:[1.] probabilidade:[0.49676368] previsão:[0.]
# real:[1.] probabilidade:[0.6060319] previsão:[1.]
# acertou:87 falhou:29
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.76      0.69        42
#          1.0       0.85      0.74      0.79        74
#
#     accuracy                           0.75       116
#    macro avg       0.74      0.75      0.74       116
# weighted avg       0.77      0.75      0.75       116
#
# [[32 10]
#  [19 55]]

# %% [markdown]
# ## *5. Usar o Modelo

# %%
# fazer uma previsão utilizando um caso
def predict(row, model):
    # converter row para tensor
    row = Tensor([row])
    # fazer a previsão
    yprev = model(row)
    # retirar o array numpy
    yprev = yprev.detach().numpy()
    return yprev
 
# fazer uma única previsão (classe esperada = 1)
row = [1,0,0.99539,-0.05889,0.85243,0.02306,0.83398,-0.37708,1,0.03760,0.85243,-0.17755,0.59755,-0.44945,0.60536,-0.38223,0.84356,-0.38542,0.58212,-0.32192,0.56971,-0.29674,0.36946,-0.47357,0.56811,-0.51171,0.41078,-0.46168,0.21266,-0.34090,0.42267,-0.54487,0.18641,-0.45300]
yprev = predict(row, model1)
print('Predicted: %.3f (class=%d)' % (yprev, yprev.round()))
yprev = predict(row, model2)
print('Predicted: %.3f (class=%d)' % (yprev, yprev.round()))
# Out:
# Predicted: 0.779 (class=1)
# Predicted: 0.510 (class=1)
