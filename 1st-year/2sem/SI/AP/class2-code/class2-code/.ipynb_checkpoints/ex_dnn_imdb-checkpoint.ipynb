# %% [markdown]
# ### Example for DNN with the IMDB dataset (including regularization)

# %% [markdown]
# Loading the dataset and checking dimensions

# %%
from tensorflow.keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

print(train_data.shape, test_data.shape)
print(len(train_labels), len(test_labels))
print(train_data[0])
print(train_labels[0])
# Out:
# 2024-02-18 17:31:05.045322: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (25000,) (25000,)
# 25000 25000
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# 1

# %% [markdown]
# Exploring and pre-processing the dataset

# %%
print(max([max(sequence) for sequence in train_data]))

word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[2]])
print(decoded_review)
# Out:
# 9999
# ? this has to be one of the worst films of the 1990s when my friends i were watching this film being the target audience it was aimed at we just sat watched the first half an hour with our jaws touching the floor at how bad it really was the rest of the time everyone else in the theatre just started talking to each other leaving or generally crying into their popcorn that they actually paid money they had ? working to watch this feeble excuse for a film it must have looked like a great idea on paper but on film it looks like no one in the film has a clue what is going on crap acting crap costumes i can't get across how ? this is to watch save yourself an hour a bit of your life

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# Defining the model structure

# %%
from tensorflow.keras import models, layers

hidden = 16

model = models.Sequential()
model.add(layers.Dense(hidden, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(hidden, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# Training the model and plotting errors along the process

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 62ms/step - loss: 0.5538 - acc: 0.7677 - val_loss: 0.4292 - val_acc: 0.8621
# Epoch 2/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3536 - acc: 0.8903 - val_loss: 0.3322 - val_acc: 0.8821
# Epoch 3/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2647 - acc: 0.9144 - val_loss: 0.2956 - val_acc: 0.8851
# Epoch 4/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2139 - acc: 0.9284 - val_loss: 0.2764 - val_acc: 0.8894
# Epoch 5/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1791 - acc: 0.9425 - val_loss: 0.2973 - val_acc: 0.8816
# Epoch 6/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1523 - acc: 0.9513 - val_loss: 0.2819 - val_acc: 0.8851
# Epoch 7/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1361 - acc: 0.9543 - val_loss: 0.2928 - val_acc: 0.8831
# Epoch 8/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 0.9637 - val_loss: 0.3082 - val_acc: 0.8790
# Epoch 9/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1012 - acc: 0.9696 - val_loss: 0.3121 - val_acc: 0.8828
# Epoch 10/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0891 - acc: 0.9746 - val_loss: 0.3410 - val_acc: 0.8750
# Epoch 11/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0809 - acc: 0.9758 - val_loss: 0.3395 - val_acc: 0.8812
# Epoch 12/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0673 - acc: 0.9827 - val_loss: 0.3624 - val_acc: 0.8801
# Epoch 13/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0580 - acc: 0.9863 - val_loss: 0.3774 - val_acc: 0.8771
# Epoch 14/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0514 - acc: 0.9888 - val_loss: 0.3956 - val_acc: 0.8777
# Epoch 15/20
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0433 - acc: 0.9905 - val_loss: 0.4193 - val_acc: 0.8782
# Epoch 16/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0386 - acc: 0.9921 - val_loss: 0.4507 - val_acc: 0.8703
# Epoch 17/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0310 - acc: 0.9951 - val_loss: 0.5116 - val_acc: 0.8678
# Epoch 18/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0282 - acc: 0.9939 - val_loss: 0.4887 - val_acc: 0.8716
# Epoch 19/20
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0222 - acc: 0.9974 - val_loss: 0.5146 - val_acc: 0.8735
# Epoch 20/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0187 - acc: 0.9983 - val_loss: 0.5343 - val_acc: 0.8720

# %%
history_dict = history.history
acc_values = history_dict['acc'] 
val_acc_values = history_dict['val_acc']
epochs = range(1, len(acc_values) + 1)

import matplotlib.pyplot as plt
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %%
loss_values = history_dict['loss'] 
val_loss_values = history_dict['val_loss']

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Predicting for the test set and calculating errors

# %%
preds = model.predict(x_test) # probabilities
class_preds = preds > 0.5

print(preds[0:5])
class_preds[0:5]
# Out:
# 782/782 [==============================] - 1s 894us/step
# [[0.01852158]
#  [0.99999875]
#  [0.96268636]
#  [0.9380477 ]
#  [0.9900842 ]]
# array([[False],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
results = model.evaluate(x_test, y_test, verbose = 0)
results
# Out:
# [0.5786918997764587, 0.8607199788093567]

# %% [markdown]
# Overfitting - controlling capacity of the model

# %%
hidden = 4

model2 = models.Sequential()
model2.add(layers.Dense(hidden, activation='relu', input_shape=(10000,)))
model2.add(layers.Dense(hidden, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

model2.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history2 = model2.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))

results2 = model2.evaluate(x_test, y_test, verbose = 0)
print(results2)

history_dict2 = history2.history
loss_values2 = history_dict2['loss'] 
val_loss_values2 = history_dict2['val_loss']

plt.plot(epochs, loss_values2, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values2, 'b', label='Validation loss')
plt.title('Training and validation loss (4 hidden neurons)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 49ms/step - loss: 0.5589 - acc: 0.7700 - val_loss: 0.4623 - val_acc: 0.8465
# Epoch 2/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3922 - acc: 0.8824 - val_loss: 0.3715 - val_acc: 0.8719
# Epoch 3/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3086 - acc: 0.9063 - val_loss: 0.3244 - val_acc: 0.8827
# Epoch 4/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2564 - acc: 0.9202 - val_loss: 0.3031 - val_acc: 0.8823
# Epoch 5/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2207 - acc: 0.9317 - val_loss: 0.2844 - val_acc: 0.8897
# Epoch 6/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1932 - acc: 0.9396 - val_loss: 0.2803 - val_acc: 0.8873
# Epoch 7/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1718 - acc: 0.9474 - val_loss: 0.2780 - val_acc: 0.8879
# Epoch 8/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1542 - acc: 0.9536 - val_loss: 0.2755 - val_acc: 0.8866
# Epoch 9/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1382 - acc: 0.9591 - val_loss: 0.2788 - val_acc: 0.8873
# Epoch 10/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1244 - acc: 0.9637 - val_loss: 0.2829 - val_acc: 0.8886
# Epoch 11/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1131 - acc: 0.9677 - val_loss: 0.2891 - val_acc: 0.8872
# Epoch 12/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1021 - acc: 0.9723 - val_loss: 0.3008 - val_acc: 0.8858
# Epoch 13/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0924 - acc: 0.9749 - val_loss: 0.3062 - val_acc: 0.8840
# Epoch 14/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0835 - acc: 0.9785 - val_loss: 0.3169 - val_acc: 0.8837
# Epoch 15/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0759 - acc: 0.9817 - val_loss: 0.3282 - val_acc: 0.8829
# Epoch 16/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0683 - acc: 0.9843 - val_loss: 0.3513 - val_acc: 0.8751
# Epoch 17/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0622 - acc: 0.9864 - val_loss: 0.3503 - val_acc: 0.8801
# Epoch 18/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0561 - acc: 0.9879 - val_loss: 0.3659 - val_acc: 0.8762
# Epoch 19/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0506 - acc: 0.9901 - val_loss: 0.3838 - val_acc: 0.8745
# Epoch 20/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0458 - acc: 0.9913 - val_loss: 0.3985 - val_acc: 0.8733
# [0.43375828862190247, 0.8627200126647949]

# %%
hidden = 64

model3 = models.Sequential()
model3.add(layers.Dense(hidden, activation='relu', input_shape=(10000,)))
model3.add(layers.Dense(hidden, activation='relu'))
model3.add(layers.Dense(1, activation='sigmoid'))

model3.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history3 = model3.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))


results3 = model3.evaluate(x_test, y_test, verbose = 0)
print(results3)

history_dict3 = history3.history
loss_values3 = history_dict3['loss'] 
val_loss_values3 = history_dict3['val_loss']

plt.plot(epochs, loss_values3, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values3, 'b', label='Validation loss')
plt.title('Training and validation loss (64 hidden neurons)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 53ms/step - loss: 0.5199 - acc: 0.7383 - val_loss: 0.3459 - val_acc: 0.8733
# Epoch 2/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3032 - acc: 0.8841 - val_loss: 0.2915 - val_acc: 0.8840
# Epoch 3/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.2274 - acc: 0.9147 - val_loss: 0.3002 - val_acc: 0.8788
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1830 - acc: 0.9321 - val_loss: 0.2885 - val_acc: 0.8871
# Epoch 5/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1589 - acc: 0.9411 - val_loss: 0.2898 - val_acc: 0.8847
# Epoch 6/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1233 - acc: 0.9564 - val_loss: 0.3068 - val_acc: 0.8828
# Epoch 7/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1130 - acc: 0.9583 - val_loss: 0.3224 - val_acc: 0.8839
# Epoch 8/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0772 - acc: 0.9751 - val_loss: 0.4109 - val_acc: 0.8705
# Epoch 9/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0820 - acc: 0.9703 - val_loss: 0.3684 - val_acc: 0.8830
# Epoch 10/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0638 - acc: 0.9817 - val_loss: 0.3930 - val_acc: 0.8804
# Epoch 11/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0582 - acc: 0.9821 - val_loss: 0.4046 - val_acc: 0.8771
# Epoch 12/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0208 - acc: 0.9977 - val_loss: 0.4456 - val_acc: 0.8771
# Epoch 13/20
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0493 - acc: 0.9865 - val_loss: 0.4617 - val_acc: 0.8765
# Epoch 14/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0367 - acc: 0.9886 - val_loss: 0.4728 - val_acc: 0.8746
# Epoch 15/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0092 - acc: 0.9995 - val_loss: 0.5116 - val_acc: 0.8737
# Epoch 16/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0326 - acc: 0.9902 - val_loss: 0.5166 - val_acc: 0.8772
# Epoch 17/20
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0053 - acc: 0.9997 - val_loss: 0.5596 - val_acc: 0.8757
# Epoch 18/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0394 - acc: 0.9893 - val_loss: 0.5493 - val_acc: 0.8736
# Epoch 19/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0033 - acc: 0.9999 - val_loss: 0.5893 - val_acc: 0.8750
# Epoch 20/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0390 - acc: 0.9891 - val_loss: 0.5839 - val_acc: 0.8744
# [0.6273963451385498, 0.8634799718856812]

# %% [markdown]
# L2 regularization

# %%
from tensorflow.keras import regularizers

hidden = 16

model_l2 = models.Sequential()
model_l2.add(layers.Dense(hidden, activation='relu', kernel_regularizer=regularizers.l2(0.001),
                       input_shape=(10000,)))
model_l2.add(layers.Dense(hidden, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model_l2.add(layers.Dense(1, activation='sigmoid'))

model_l2.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history_l2 = model_l2.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))

history_l2_dict = history_l2.history
loss_values_l2 = history_l2_dict['loss'] 
val_loss_values_l2 = history_l2_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.plot(epochs, loss_values_l2, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values_l2, 'b', label='Validation loss')
plt.title('Training and validation loss - L2 regularizer')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

results_l2 = model_l2.evaluate(x_test, y_test, verbose = 0)
results_l2
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 45ms/step - loss: 0.6076 - acc: 0.7786 - val_loss: 0.4980 - val_acc: 0.8327
# Epoch 2/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.4142 - acc: 0.8826 - val_loss: 0.3875 - val_acc: 0.8788
# Epoch 3/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3267 - acc: 0.9081 - val_loss: 0.3538 - val_acc: 0.8814
# Epoch 4/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2826 - acc: 0.9197 - val_loss: 0.3342 - val_acc: 0.8885
# Epoch 5/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2537 - acc: 0.9320 - val_loss: 0.3295 - val_acc: 0.8898
# Epoch 6/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2339 - acc: 0.9409 - val_loss: 0.3369 - val_acc: 0.8865
# Epoch 7/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2152 - acc: 0.9485 - val_loss: 0.3360 - val_acc: 0.8862
# Epoch 8/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2094 - acc: 0.9475 - val_loss: 0.3530 - val_acc: 0.8805
# Epoch 9/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1950 - acc: 0.9575 - val_loss: 0.3857 - val_acc: 0.8735
# Epoch 10/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1885 - acc: 0.9586 - val_loss: 0.3568 - val_acc: 0.8814
# Epoch 11/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1861 - acc: 0.9597 - val_loss: 0.3643 - val_acc: 0.8806
# Epoch 12/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1755 - acc: 0.9643 - val_loss: 0.3868 - val_acc: 0.8733
# Epoch 13/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1734 - acc: 0.9663 - val_loss: 0.4003 - val_acc: 0.8754
# Epoch 14/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1647 - acc: 0.9683 - val_loss: 0.4150 - val_acc: 0.8682
# Epoch 15/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1637 - acc: 0.9696 - val_loss: 0.3919 - val_acc: 0.8774
# Epoch 16/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1606 - acc: 0.9705 - val_loss: 0.3988 - val_acc: 0.8755
# Epoch 17/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1576 - acc: 0.9718 - val_loss: 0.4128 - val_acc: 0.8719
# Epoch 18/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1498 - acc: 0.9753 - val_loss: 0.4157 - val_acc: 0.8742
# Epoch 19/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1483 - acc: 0.9763 - val_loss: 0.4379 - val_acc: 0.8657
# Epoch 20/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1436 - acc: 0.9774 - val_loss: 0.4277 - val_acc: 0.8733
# [0.44980284571647644, 0.8638399839401245]

# %% [markdown]
# Dropout

# %%
model_dr = models.Sequential()
model_dr.add(layers.Dense(hidden, activation='relu', input_shape=(10000,)))
model_dr.add(layers.Dropout(0.5))
model_dr.add(layers.Dense(hidden, activation='relu'))
model_dr.add(layers.Dropout(0.5))
model_dr.add(layers.Dense(1, activation='sigmoid'))

model_dr.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history_dr = model_dr.fit(partial_x_train,
                    partial_y_train,
                    epochs=10,
                    batch_size=512,
                    validation_data=(x_val, y_val))

history_dr_dict = history_dr.history
loss_values_dr = history_dr_dict['loss'] 
val_loss_values_dr = history_dr_dict['val_loss']
epochs = range(1, len(loss_values_dr) + 1)

plt.plot(epochs, loss_values_dr, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values_dr, 'b', label='Validation loss')
plt.title('Training and validation loss - dropout')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

results_dr = model_dr.evaluate(x_test, y_test, verbose = 0)
results_dr
# Out:
# Epoch 1/10
# 30/30 [==============================] - 2s 41ms/step - loss: 0.6537 - acc: 0.6111 - val_loss: 0.5835 - val_acc: 0.8340
# Epoch 2/10
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5499 - acc: 0.7427 - val_loss: 0.4548 - val_acc: 0.8641
# Epoch 3/10
# 30/30 [==============================] - 0s 12ms/step - loss: 0.4636 - acc: 0.8051 - val_loss: 0.3632 - val_acc: 0.8739
# Epoch 4/10
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3899 - acc: 0.8456 - val_loss: 0.3188 - val_acc: 0.8825
# Epoch 5/10
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3383 - acc: 0.8714 - val_loss: 0.3035 - val_acc: 0.8781
# Epoch 6/10
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2899 - acc: 0.8927 - val_loss: 0.2743 - val_acc: 0.8900
# Epoch 7/10
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2592 - acc: 0.9064 - val_loss: 0.2707 - val_acc: 0.8899
# Epoch 8/10
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2298 - acc: 0.9204 - val_loss: 0.2742 - val_acc: 0.8885
# Epoch 9/10
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2021 - acc: 0.9317 - val_loss: 0.2828 - val_acc: 0.8871
# Epoch 10/10
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1827 - acc: 0.9414 - val_loss: 0.2936 - val_acc: 0.8881
# [0.3092617690563202, 0.8823599815368652]

# %% [markdown]
# Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

hidden = 16

model = models.Sequential()
model.add(layers.Dense(hidden, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(hidden, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

early = EarlyStopping(monitor='val_loss', min_delta=0, patience= 5, verbose= True, mode='auto')

callbacks = [early]
history_es = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    callbacks = callbacks)

history_dict_es = history_es.history
loss_values_es = history_dict_es['loss'] 
val_loss_values_es = history_dict_es['val_loss']
epochs = range(1, len(loss_values_es) + 1)

plt.plot(epochs, loss_values_es, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values_es, 'b', label='Validation loss')
plt.title('Training and validation loss (early stopping)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

results_es = model.evaluate(x_test, y_test, verbose = 0)
results_es
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 43ms/step - loss: 0.5276 - acc: 0.7703 - val_loss: 0.3983 - val_acc: 0.8634
# Epoch 2/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3243 - acc: 0.8931 - val_loss: 0.3285 - val_acc: 0.8733
# Epoch 3/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2450 - acc: 0.9174 - val_loss: 0.2838 - val_acc: 0.8884
# Epoch 4/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1982 - acc: 0.9335 - val_loss: 0.2747 - val_acc: 0.8892
# Epoch 5/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1645 - acc: 0.9459 - val_loss: 0.2816 - val_acc: 0.8855
# Epoch 6/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1421 - acc: 0.9519 - val_loss: 0.2964 - val_acc: 0.8851
# Epoch 7/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1227 - acc: 0.9623 - val_loss: 0.3020 - val_acc: 0.8854
# Epoch 8/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1042 - acc: 0.9686 - val_loss: 0.3076 - val_acc: 0.8816
# Epoch 9/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0907 - acc: 0.9743 - val_loss: 0.3264 - val_acc: 0.8830
# Epoch 9: early stopping
# [0.34769293665885925, 0.8713200092315674]
