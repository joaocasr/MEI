# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#USING CROSS VALIDATION
from sklearn.model_selection import cross_val_score

# %%
'''
Load dos datasets e merge de ambos por 'Area Code' e 'Phone'
'''
callsexcel = pd.read_excel('CallsData.xls')
contractdatacsv = pd.read_csv('ContractData.csv')

allData = callsexcel.merge(contractdatacsv,how="inner",on=["Area Code","Phone"])

# %%
#allData_wbinary = pd.get_dummies(allData, columns=['Churn']) converter categorico em binario
allData['Churn'] = allData['Churn'].map({0: 'Permaneceu', 1: 'Abandonou'})
allData
# Out:
#       VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0                25     265.1     197.4       244.7       10.0
# 1                26     161.6     195.5       254.4       13.7
# 2                 0     243.4     121.2       162.6       12.2
# 3                 0     299.4      61.9       196.9        6.6
# 4                 0     166.7     148.3       186.9       10.1
# ...             ...       ...       ...         ...        ...
# 3328             36     156.2     215.5       279.1        9.9
# 3329              0     231.1     153.4       191.3        9.6
# 3330              0     180.8     288.8       191.9       14.1
# 3331              0     213.8     159.6       139.2        5.0
# 3332             25     234.4     265.9       241.4       13.7
#
#       CustServ Calls  Day Calls  Day Charge  Eve Calls  Eve Charge  ...  \
# 0                  1        110       45.07         99       16.78  ...
# ...

# %%
X = allData.drop(['Churn'],axis=1)
Y = allData['Churn'].to_frame()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=12345) #random_state->seed

X_train = X_train.drop(['State','Phone'], axis=1)  
X_test = X_test.drop(['State','Phone'], axis=1)    

clf = DecisionTreeClassifier(random_state=12345)

clf.fit(X_train, Y_train)
predictions = clf.predict(X_test)

# %%
accuracy_score(Y_test, predictions)
# Out:
# 0.902

# %%
f1_score(Y_test, predictions, average='macro')
# Out:
# 0.8139202819297606

# %%
from sklearn.model_selection import KFold
scores = []
i=0
kf = KFold(n_splits=10)
for train, test in kf.split(X): 
    clf.fit(X.loc[train,:],Y.loc[train,:])
    score = clf.score(X.loc[test,:],Y.loc[test,:])
    scores.append(score)
    y_predicted = clf.predict(X.loc[test,:])
    print("Confusion Matrix:")
    print(confusion_matrix(Y.loc[test,:], y_predicted))
    print(score)
print("RESULT: %0.2f accuracy with a standard deviation of %0.2f" % (np.mean(scores),np.std(scores)))
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15108\4117825427.py in ?()
#       4 kf = KFold(n_splits=10)
#       5 for train, test in kf.split(X):
#       6     print(i)
#       7     i+=1
# ----> 8     clf.fit(X.loc[train,:],Y.loc[train,:])
#       9     score = clf.score(X.loc[test,:],Y.loc[test,:])
#      10     scores.append(score)
#      11     y_predicted = clf.predict(X.loc[test,:])
#
# c:\Users\joaop\miniconda3\envs\mypython3version\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
confusion_matrix(Y_test, predictions)
# Out:
# array([[107,  46],
#        [ 52, 795]], dtype=int64)
